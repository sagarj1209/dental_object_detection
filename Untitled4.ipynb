# %% [markdown]
# <a href="https://colab.research.google.com/github/sagarj1209/dental_object_detection/blob/master/Untitled4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 974.5/974.5 kB 24.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 58.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 50.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 94.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="MC8wQn0Jp7b1MVJ6B3JX")
project = rf.workspace("sagar-zoa1r").project("dentalxraydetection")
version = project.version(1)
dataset = version.download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
# !ls /content/DentalXrayDetection-1
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
yaml_path = "/content/DentalXrayDetection-1/data.yaml"

yaml_content = """
train: /content/DentalXrayDetection-1/train/images
val: /content/DentalXrayDetection-1/valid/images
test: /content/DentalXrayDetection-1/test/images

nc: 6
names: ['Badly Decayed', 'Caries', 'Crown', 'Normal', 'RCT', 'Restoration']
"""

with open(yaml_path, "w") as f:
    f.write(yaml_content)

print("✅ data.yaml updated successfully!")
# Out:
# ✅ data.yaml updated successfully!

# %%
# !cat /content/DentalXrayDetection-1/data.yaml
# Out:
# train: /content/DentalXrayDetection-1/train/images
# val: /content/DentalXrayDetection-1/valid/images
# test: /content/DentalXrayDetection-1/test/images
#
# nc: 6
# names: ['Badly Decayed', 'Caries', 'Crown', 'Normal', 'RCT', 'Restoration']

# %%
model = YOLO("yolov8n.pt")  # You can also try 'yolov8s.pt', 'yolov8m.pt', etc.

results = model.train(
    data="/content/DentalXrayDetection-1/data.yaml",  # Update this path if needed
    epochs=30,
    imgsz=640,
    batch=16
)
# Out:
# Ultralytics 8.3.107 🚀 Python-3.11.12 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import files
files.download('/content/runs/detect/train3/weights/best.pt')

# %%
# Load the trained model
model = YOLO('/content/runs/detect/train3/weights/best.pt')

# Predict on test images
results = model.predict(source='/content/DentalXrayDetection-1/test/images', save=True, conf=0.25)
# Out:
# image 1/54 /content/DentalXrayDetection-1/test/images/-1007-_png.rf.1dccbcdbce8e4b67b8eb8c318b93d6ff.jpg: 640x640 1 Crown, 1 Normal, 1 RCT, 30.9ms
# image 2/54 /content/DentalXrayDetection-1/test/images/-1029-_png.rf.a4ff98f71ec52688b899baf50c6cd18c.jpg: 640x640 3 RCTs, 24.7ms
# image 3/54 /content/DentalXrayDetection-1/test/images/-1031-_png.rf.5a7bebb4a593f2b33b97e66a91cfe757.jpg: 640x640 1 RCT, 1 Restoration, 34.6ms
# image 4/54 /content/DentalXrayDetection-1/test/images/-1036-_png.rf.9ef17b89aac43350e81530c437314054.jpg: 640x640 1 Badly Decayed, 1 Normal, 2 RCTs, 36.9ms
# image 5/54 /content/DentalXrayDetection-1/test/images/-1037-_png.rf.84aca7857b3110ec371df17e6f7d3057.jpg: 640x640 1 Badly Decayed, 1 Normal, 3 RCTs, 21.9ms
# image 6/54 /content/DentalXrayDetection-1/test/images/-173-_jpg.rf.c9dd93ea7202e3b0985859d0bb8267ee.jpg: 640x640 1 Normal, 2 Restorations, 29.8ms
# ...

# %%
from IPython.display import Image, display
import glob

# Display a few predicted images
for img_path in glob.glob('/content/runs/detect/predict/*.jpg')[:5]:
    display(Image(filename=img_path))
